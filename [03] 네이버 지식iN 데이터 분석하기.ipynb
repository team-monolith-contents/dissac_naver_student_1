# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">지식iN 데이터를
# 분석해보자!</div>
#     <div style="font-weight: bold; font-size: 20px">[03] 네이버 지식iN 데이터 분석하기</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     - 지식iN 데이터를 탐색하면서 다양한 데이터를 확인해봅시다.<br>
#     - 지식iN 데이터 수집방법을 탐색하고 데이터를 분석해봅시다.<br>
#     - 지식iN 데이터 분석 결과를 바탕으로 지식iN 홍보 이벤트를 기획해봅시다.<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 지식iN 분야별 질문, 답변수 분석하기</h2>
# </div>

# %% [markdown]
# ![image.png](attachment:2e738518-8e4c-4ca9-814d-a08f242d67a6.png)
#
# 지식iN에서 월별로 질문의 유형을 정리한 엑셀파일이 있습니다. 가로축에는 기간이, 세로축에는 다양한 분야가 적혀있습니다.
# 가로축은 ‘행’, 세로축은 ‘열’이라고 부릅니다. 각 행과 열에는 컴퓨터 통신, 게임, 엔터테인먼트, 경제, 건강 등 다양한
# 분야에 질문과 답변 수가 월별로 얼마나 있었는지 표현되어 있습니다.
#
# <br>
#
# ![image.png](attachment:c54b638a-22a9-40e9-ae83-d4bc44db85d8.png)
#
# 표로 제시되어 있는데 굉장히 복잡해 보이죠?
# [엔트리 작품만들기](https://playentry.org/ws#!/)에 접속하면 표의 데이터를 분석할 수 있습니다.
#
# 파이썬 코드로도 데이터를 분석할 수 있는 방법이 있습니다. 바로 파이썬의 Pandas와 Pyplot 라이브러리를 활용하는 것입니다.
#
# 이번 챕터에서는 파이썬의 Pandas와 Pyplot 라이브러리를 활용하여 지식in 데이터를 분석해봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">📌 수업 TIP </div>
#     <a        href   =   "https://blog.naver.com/nvplaysw/222162691603"> 엔트리 실습 링크 </a>(https://blog.naver.com/nvplaysw/222162691603)에서 지식iN 데이터 파일을 다운받아 실습을
# 진행합니다.
#
# </div>

# %% [markdown]
# ### **<STEP 1> 라이브러리 불러오기**

# %% [markdown]
# 1. `import` 명령어를 활용하여 Pandas 라이브러리를 가져올 수 있습니다.
# 하단의 셀을 실행시켜 Pandas 라이브러리를 불러옵니다.

# %%
import pandas as pd  # Pandas를 pd로 축약하여 불러옵니다
import matplotlib.pyplot as plt  # Pyplot을 plt로 축약하여 불러옵니다

# %% [markdown]
# ### **<STEP 1> 데이터 불러오기**

# %% [markdown]
# 1) `pd.read_excel(파일 경로)` 함수를 활용하여 엑셀 파일을 불러올 수 있습니다.
# 괄호 안의 `파일 경로` 부분에는 각자 파일을 저장한 경로를 작성하면 됩니다.

# %%
# pd.read_excel(파일경로) 함수를 활용하여 엑셀 파일을 데이터프레임 형식으로 불러와봅시다.
df = pd.read_excel('https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/2019_%EC%A7%80%EC%8B%9DiN_Q%26A_%ED%86%B5%EA%B3%84.xlsx')

# %% [markdown]
# 2) `df.info()` 함수를 사용하면 각 열의 이름, 비어있지 않은 값의 개수, 열의 자료형 등 여러가지 정보를 확인할 수 있습니다.

# %%
# df.info() 함수를 사용하여 데이터의 정보를 확인해봅시다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   기간                12 non-null     object
#  1   컴퓨터통신 신규 질문       12 non-null     int64
#  2   컴퓨터통신 신규 답변       12 non-null     int64
#  3   게임 신규 질문          12 non-null     int64
#  4   게임 신규 답변          12 non-null     int64
#  5   엔터테인먼트, 예술 신규 질문  12 non-null     int64
#  6   엔터테인먼트, 예술 신규 답변  12 non-null     int64
#  7   경제 신규 질문          12 non-null     int64
#  8   경제 신규 답변          12 non-null     int64
#  9   쇼핑 신규 질문          12 non-null     int64
#  10  쇼핑 신규 답변          12 non-null     int64
#  11  사회, 정치 신규 질문      12 non-null     int64
#  12  사회, 정치 신규 답변      12 non-null     int64
#  13  건강 신규 질문          12 non-null     int64
#  14  건강 신규 답변          12 non-null     int64
#  15  생활 신규 질문          12 non-null     int64
# ...

# %% [markdown]
# 3) `df.describe()` 함수를 사용하면 각 열의 데이터 평균, 표준편차 등의 통계 정보를 확인할 수 있습니다.

# %%
# df.describe() 함수를 사용하여 데이터의 통계 정보를 확인해봅시다.
# Out:
#          컴퓨터통신 신규 질문    컴퓨터통신 신규 답변      게임 신규 질문       게임 신규 답변  \
# count      12.000000      12.000000     12.000000      12.000000
# mean   209668.000000  318948.000000  68850.000000  139975.083333
# std     19424.439334  170852.744473  14584.709253  126598.447178
# min    180822.000000  208981.000000  45449.000000   52480.000000
# 25%    199157.750000  242410.500000  58067.000000   69872.250000
# 50%    208530.500000  251142.000000  69347.500000   90678.000000
# 75%    226106.500000  298008.500000  75116.500000  127063.250000
# max    238651.000000  815037.000000  98541.000000  483631.000000
#
#        엔터테인먼트, 예술 신규 질문  엔터테인먼트, 예술 신규 답변       경제 신규 질문       경제 신규 답변  \
# count          12.00000      1.200000e+01      12.000000      12.000000
# mean       163323.00000      8.327642e+05  172104.916667  396775.750000
# std         15606.72785      1.089395e+06   15527.216401   91211.551302
# min        140058.00000      1.540680e+05  153103.000000  314694.000000
# ...

# %% [markdown]
# ### **<STEP 2> 그래프로 표현하기**

# %% [markdown]
# 1) 앞서 데이터를 `df`라는 변수에 저장했습니다. `df`를 셀에 작성하고 실행하면 파일에서 볼 수 있었던 표가 나옵니다.
# 하단의 셀을 실행해보면 알수 있듯 표가 매우 복잡합니다. 따라서 그래프로 표현하여 확인하도록 하겠습니다.

# %%
# 데이터를 출력해봅시다.
# Out:
#      기간  컴퓨터통신 신규 질문  컴퓨터통신 신규 답변  게임 신규 질문  게임 신규 답변  엔터테인먼트, 예술 신규 질문  \
# 0    1월       238651       242700     98541    107915            184794
# 1    2월       233331       278634     84282     94372            163477
# 2    3월       212577       216138     57428     64242            147779
# 3    4월       180822       208981     45449     52480            140151
# 4    5월       183791       241542     52007     61327            140058
# 5    6월       186392       247549     58280     71749            156790
# 6    7월       205284       254735     73305     79184            170351
# 7    8월       224866       356132     77995    182216            183947
# 8    9월       208816       458894     67510    286922            161889
# 9   10월       229828       815037     74157    483631            182769
# 10  11월       208245       262136     66061    108679            164091
# 11  12월       203413       244898     71185     86984            163780
#
# ...

# %% [markdown]
# 2) `df.plot(x, y, kind="bar")`와 같이 작성하면 가로축이 x, 세로축이 y인 막대 그래프를 그릴 수 있습니다.
# `plt.show()` 함수를 사용하면 그래프를 화면에 출력할 수 있습니다.

# %%
df.plot(x='기간', y='컴퓨터통신 신규 질문', kind='bar', figsize=(5,3)) 
plt.show()

# %% [markdown]
# 3) x축, 즉 가로축에는 우리의 표 데이터 중 `기간` 데이터를 사용하고자 합니다.

# %%
# x축 값을 설정해봅시다.

# %% [markdown]
# 4. y축, 즉 세로축 데이터로는 먼저 '기간'을 제외한 모든 열을 사용해봅시다.
# `df.columns`은 모든 열의 이름을 반환합니다.

# %%
# y축 값을 설정해봅시다. (열값 중 '기간'을 제외해야합니다.)
# Out:
# Index(['컴퓨터통신 신규 질문', '컴퓨터통신 신규 답변', '게임 신규 질문', '게임 신규 답변',
#        '엔터테인먼트, 예술 신규 질문', '엔터테인먼트, 예술 신규 답변', '경제 신규 질문', '경제 신규 답변',
#        '쇼핑 신규 질문', '쇼핑 신규 답변', '사회, 정치 신규 질문', '사회, 정치 신규 답변', '건강 신규 질문',
#        '건강 신규 답변', '생활 신규 질문', '생활 신규 답변', '여행 신규 질문', '여행 신규 답변',
#        '스포츠, 레저 신규 질문', '스포츠, 레저 신규 답변', '교육, 학문 신규 질문', '교육, 학문 신규 답변',
#        '지역&플레이스 신규 질문', '지역&플레이스 신규 답변', '쥬니버Q&A 신규 질문', '쥬니버Q&A 신규 답변',
#        '고민Q&A 신규 질문', '고민Q&A 신규 답변'],
#       dtype='object')

# %%
# 위에서 정의한 x, y축 값으로 막대그래프(bar)를 그려봅시다. (figsize=(18,8))

# %% [markdown]
# 5) 분야별로 여러 색상으로 구분되어 막대그래프로 표현되는 것을 확인할 수 있습니다.

# %% [markdown]
# ### **<STEP 3> 특정 분야만 선택한 그래프 확인하기**

# %% [markdown]
# 6)
# 값이 너무 많아서 보기 쉽지 않죠? 원하는 세로축 열 이름을 y값으로 지정해서 한 가지 분야만 선택해서 그래프로 표현할 수도 있습니다.
# 자유롭게 분야를 바꿔가며 그래프를 살펴봅시다.

# %%
# y축 값을 특정 분야로 지정해서 막대 그래프를 그려봅시다.(figsize=(5,3))

# %%
# y축 값으로 여러 값을 선택하여 막대 그래프를 그려봅시다. (figsize=(5,3))
df.plot(x, y=['경제 신규 질문', '여행 신규 질문'], kind="bar",figsize=(5,3))
plt.show()

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 질문이 가장 많은 월(달) 확인하고 이유 분석하기</h2>
# </div>

# %% [markdown]
# 그래프를 통해 분석하면서 질문에 답해봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 1</div>
#     <br>
# 어떤 분야에 대한 질문과 답변이 많은가요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 2</div>
#     <br>
# 몇 월에 질문과 대답이 가장 많았나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# ![image.png](attachment:31fa9d59-4967-4a8c-8de6-0088a8716fa6.png)
#
# 질문과 답변수를 보면 10월에 유난히 수치가 높은 것을 확인할 수 있습니다.
# 네이버 검색을 통해 2019년 10월에 무슨 일이 있었는지 조사해봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 3</div>
#     <br>
# 무슨 일이 있었나요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# ![image.png](attachment:52df0eeb-771f-46ae-b3ef-57a90e14ca3f.png)
#
# 2019년 10월에 네이버 지식iN 17주년 이벤트가 있었습니다.
# 다른 기간에 비해 이벤트 기간 동안 지식iN에서 질문과 답변수가 평소보다 확연히 늘었다는 사실을 데이터 분석을 통해 확인할 수 있습니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">🚄 쉬어가기 (2)</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 스토리텔링의 중요성</div>
#
# </div>

# %% [markdown]
# ### **1) 스토리텔링(Storytelling)이란?**
#
# ---

# %% [markdown]
# '스토리(story) + 텔링(telling)'의 합성어로서 말 그대로 '이야기하다'라는 의미를 지닙니다. 즉 상대방에게 알
# 리고자 하는 바를 재미있고 생생한 이야기로 설득력 있게 전달하는 행위입니다. 스토리텔링은 원래 문학이나
# 영화, 교육학 등에서 활용되던 방법이었습니다. 오늘날 우리 일상생활에서 스토리텔링은 여러 가지로 유익하고
# 설득력 있는 수단으로 이용되고 있습니다. 인류가 등장한 이래 스토리텔링은 인간끼리의 의사소통에 있어 늘
# 중심적인 역할을 해왔기 때문입니다. 스토리텔링은 매체의 특성에 따라 다양하게 발현되고 하는데, 영화·비디
# 오·애니메이션·만화·게임·광고 등의 원천적인 콘텐츠로 활용되고 있습니다.
# <br>
# [출처 : 네이버 지식백과] 스토리텔링 (문학비평용어사전, 2006. 1. 30., 한국문학평론가협회)

# %% [markdown]
# ### **2) 전문가 인터뷰**
#
# ---

# %% [markdown]
# *"라인(LINE)에서는 일본에서 ‘코노미’라는 프로그램을 통해 맛집 추천을 해줍니다.
# 초기에는 사람들이 먹었던 음식에 대한 기록을 바탕으로 순위를 매겨 추천을 했는
# 데 반응이 좋지 않았습니다. 그래서 스토리를 넣어 ‘이 음식점은 당신이 3일 전에
# 먹었던 음식처럼 매운 음식을 팔고 있습니다’와 같이 제시해보았더니, 오히려 사
# 용자들이 더 많은 관심을 보였습니다. 데이터분석에 가장 중요하게 다뤄지는 것은
# ‘스토리’입니다. 기술이 아니라, 스토리를 만들어내고 제시한 다음, 반응에 따라 수
# 정해나가는 것이 매우 중요한 화두라고 할 수 있습니다."*
#
# \- 김광림님 인터뷰(네이버 데이터랩 데이터 엔지니어)

# %% [markdown]
# ### **3) 1년에 1095개 vs 하루에 3개?**
#
# ---

# %% [markdown]
# 같은 내용이라도 어떻게 표현하느냐에 따라 사람들에게 다른 느낌을 줄 수 있습니다. 사과를 1년 동안 1095개
# 를 먹는다고 하는 것과 매일 3개를 먹는다고 했을 때 느낌이 비슷한가요? 같은 내용이라도 이야기를 어떻게 풀
# 어내느냐가 중요합니다. 데이터 분석에서도 ‘스토리텔링’을 잘 활용할 필요가 있습니다.
