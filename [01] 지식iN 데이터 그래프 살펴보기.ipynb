# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">지식iN 데이터를
# 분석해보자!</div>
#     <div style="font-weight: bold; font-size: 20px">[01] 지식iN 데이터 그래프 살펴보기</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     - 지식iN 데이터를 탐색하면서 다양한 데이터를 확인해봅시다.<br>
#     - 지식iN 데이터 수집방법을 탐색하고 데이터를 분석해봅시다.<br>
#     - 지식iN 데이터 분석 결과를 바탕으로 지식iN 홍보 이벤트를 기획해봅시다.<br>
# </div>

# %% [markdown]
# ![image.png](attachment:39cc4f2c-51d1-49f8-83e9-05e5e19fb521.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 지식in을 사용해본 적이 있나요?</h2>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 여러분은 평소에 지식iN을 많이 활용하나요? 어떤 정보를 찾아본 경험이 있나요?<br>
# 지식iN을 활용해 궁금증을 해결했던 경험을 각자 이야기해 봅시다.
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 그래프의 개념 익히기</h2>
# </div>

# %% [markdown]
# 이번 프로젝트에서 등장하는 그래프를 미리 살펴봅시다.
# 그래프를 통해 데이터를 한 눈에 보기 좋게 표현할 수 있습니다.

# %% [markdown]
# ### **1) 막대 그래프**
# ![image.png](attachment:25afd7bf-904b-45c2-941a-e4217ac2a2e5.png)
#
# **<막대 그래프 개념>**
# - 비교할 양이나 수치의 분포를 막대 모양의 도형으로 나타낸 그래프.
# - 수량의 많고 적음을 한 눈에 비교할 수 있음.
#
# **<막대 그래프 그리는 법>**
# 1. 가로와 세로 눈금에 나타낼 것을 정한다.
# 2. 세로 눈금 한 칸의 크기를 정한다.
# 3. 조사한 수에 알맞게 막대를 그린다.

# %% [markdown]
# ### **2) 원 그래프**
# ![image.png](attachment:a69470bd-376e-41ee-a96c-f16af2b16022.png)
#
# **<원 그래프 개념>**
# - 전체에 대한 각 항목의 비율을 원 모양으로 나타낸 그래프.
# - 비율그래프의 한 종류로 전체에 대한 부분의 비율을 한눈에 알 수 있다.
#
# **<원 그래프 그리는 법>**
# 1. 자료를 보고, 각 항목의 백분율을 구한다.(백분율의 합계가 100%인지 확인한다.)
# 2. 각 항목별 백분율의 크기만큼 선을 그어 띠를 나눈다.
# 3. 각 항목별 원 위에 항목의 이름과 백분율의 크기를 쓴다

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 지식iN의 여러 가지 데이터 확인하기</h2>
# </div>

# %% [markdown]
# ### **1) 네이버 지식in 서비스란?**

# %% [markdown]
# 먼저 네이버 지식iN이 어떤 서비스인지 구체적으로 알아보겠습니다.  <br><br>
#
#
# ![image.png](attachment:0d17e82a-9b99-4771-a5bd-c5c81f472ca0.png)
#
#
# **네이버 지식iN(지식인)** 은 네이버 포털의 지식 교류 서비스입니다. 사용자가 올린 질문이나 궁금한 내용,
# 고민에 대해 다른 사용자들이 자발적으로 답변을 달면서 지식을 주고받을 수 있습니다. 2002년 10월 정
# 식 서비스를 시작한 네이버 지식iN은 2012년 9월 기준으로 질문의 수가 1억 건을 돌파했습니다. 누적
# 답변수는 2019년 6월 기준으로 무려 3억 개 이상을 기록하기도 했지요. 최근에는 변호사, 의사 등 전문
# 가 상담을 도입하여 답변 신뢰도를 높이고 있습니다.

# %% [markdown]
# ### **2) 지식in의 데이터 확인하기**

# %% [markdown]
# 네이버 지식iN(지식인)에 있는 여러 가지 데이터를 확인해봅시다.
#
#
# 지식iN **‘Q&A’** 에 접속하여 어떤 정보가 있는지 직접 확인해보세요.  <br><br>
#
# ![image.png](attachment:93a4f198-db01-4c01-8300-a61b88401356.png)
#
# <br><br>
#
# 지식iN **‘베스트’** 에 접속하여 어떤 정보가 있는지 직접 확인해보세요.
#
# ![image.png](attachment:d3b577b3-93bf-4fcf-be87-62594b2eeb72.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 1</div>
#     <br>
# 지식in에 어떤 종류의 데이터가 얼마나 있는지 알아보고, python dictionary 형태로 저장해볼까요?
# </div>

# %% [markdown]
# 파이썬에는 dictionary라는 자료형이 있습니다. dictionary는 `{key1:value1, key2:value2, ...}`의 형태로 생성할 수 있습니다.
# 우리는 데이터 이름을 key, 해당 데이터의 개수를 value로 해서 딕셔너리를 선언해봅시다.
# 개수 정보가 없는 데이터는 0개로 간주합니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #a94442; border-color: #ebccd1;">
#     <div style="font-weight: bold; font-size: 20px">💣 주의</div>
#     변수명을 자료와 동일하게 작성해주세요.<br>
#
# </div>

# %%
# 데이터 이름을 key로, 해당 데이터의 개수를 value로 한 딕셔너리를 생성해 봅시다. 
data = ???

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 2</div>
#     <br>
# 지식in 데이터 종류 중 개수를 확인하고자 하는 데이터 이름을 입력 받아 해당 데이터의 개수를 출력해봅시다.
# </div>

# %% [markdown]
# 1. `딕셔너리명[key값]`과 같은 코드를 사용하면 딕셔너리의 key값으로 value값에 접근할 수 있습니다.
# 예를 들어 `dict = {'a':1, 'b':2}`와 같은 딕셔너리가 있을 때, `dict['a']`를 출력하면 'a'의 value값인 1이 출력됩니다.
#
# 2. `input()` 함수를 활용하면 사용자에게 입력을 받을 수 있습니다.
#
# 3. `print(값)` 함수를 활용하면 괄호 안에 작성된 값을 화면에 출력할 수 있습니다.

# %%
#방금 전에 정의한 data 딕셔너리를 활용해서 코드를 작성하도록 합니다.
# Out:
# 조회하고자 하는 데이터 이름을 입력해주세요:  건강
# 22774577

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 3</div>
#     <br>
# 지식in 데이터의 양은 총 얼마나 될까요?
# </div>

# %% [markdown]
# 1. `딕셔너리명.values()` 코드는 딕셔너리의 value들의 집합을 반환해줍니다.
#
# 2. `sum()`이라는 함수는 특정 집합에 대해서 숫자들의 총합을 알려줍니다.
# 1번에서 살펴본 딕셔너리 value들의 집합에 적용한다면 어떻게 될지 생각해보세요.

# %%
# 각 데이터 개수의 총합을 출력해봅시다.
# Out:
# 240056771

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 4</div>
#     <br>
# 지식iN 데이터를 분석하면 무엇을 알 수 있을지 예상해볼까요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>4. 지식iN 명예의 전당에서 원 그래프 확인하기</h2>
# </div>

# %% [markdown]
# **'지식iN 명예의 전당'** 에서는 여러 가지 데이터를 시각화하여 만든 그래프를 월별로 제공하고 있습니다.
# 하나씩 클릭해보면서 어떤 그래프들이 있는지 확인해봅시다.   <br>
#
# ![image.png](attachment:742d85c4-9d94-4ef0-9ebb-3aae57dd9311.png)
# <br><br>
#
# <div style="font-weight: bold; font-size: 16px">✔️ 지식iN 명예의 전당: 원그래프</div>
#
# ‘명예의 전당’ 아래쪽을 보면, 지식iN 관심사를 표현한 원 그래프를 확인할 수 있습니다.  <br>
#
# ![image.png](attachment:21eb75b3-a2f6-4d9e-b46f-cbddb8ab394d.png)
# <br>
#
# 위 그래프는 2020년 1월에 10대 남성이 지식iN에서 어떤 분야에 대한 질문을 많이 올렸는지 한 눈에 알아볼 수 있도록 표현해줍니다.  <br><br>
#
# ![image.png](attachment:ca652c37-4279-4998-af46-b5c32a5fa946.png)
# <br>
#
# 위 그래프는 2020년 7월에 10대 여성이 지식iN에서 어떤 분야에 대한 질문을 많이 올렸는지 한 눈에 알아볼 수 있도록 표현해줍니다. <br><br>
#
# <div style="font-weight: bold; font-size: 16px">✔️ 지식iN 명예의 전당: 세부사항 설정</div>
#
# 화면을 위쪽으로 올려보면 기간(시간)을 변경할 수도 있습니다. 기간을 변경해 보며 원 그래프가 어떻게 달라지는지 확인해보세요.  <br>
#
# ![image.png](attachment:6cfb8a94-f282-45fe-8e4a-c593e0c57aee.png)
# <br><br>
#
# 사람들이 어떤 분야에 관심을 가지는지 기간, 성별, 나이를 설정해서 확인해보세요. <br><br>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 1</div>
#     <br>
# 2019년 10대 남자와 2017년 20대 여자의 관심분야 순위 데이터를 살펴보고, <br>
#     각 관심분야 정보를 순위가 높은 순으로 리스트에 저장해봅시다.
# </div>

# %% [markdown]
# 파이썬에는 list라는 여러 개의 자료를 저장할 수 있는 자료형이 있습니다.
# list는 대괄호([ ])를 사용해서 `[value1, value2, ...]`와 같이 선언할 수 있습니다.

# %%
# 관심분야 순위 데이터를 담은 list를 생성해봅시다.
m2019_10 = ???
f2017_10 = ???

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 2</div>
#     <br>
# 성별, 연도, 나이대, 관심도 비율 순위 정보를 입력받아 해당 관심분야명을 출력해봅시다.
# </div>

# %% [markdown]
# 1. 성별, 연도, 나이대를 입력받습니다.

# %%
# 성별, 연도, 나이배를 입력받는 명령어를 작성해봅시다.(입력 예시: 여자 2017년 10대)
# Out:
# 성별, 연도, 나이대를 입력하세요(입력 예시: 여자 2017년 10대):  여자 2017년 10대

# %% [markdown]
# 2. 조건문을 활용하여 입력된 정보에 해당하는 리스트를 출력해봅시다.
# 앞선 워크시트1에서 정의한 리스트를 활용합니다.
# - 조건문은 `조건`이 참일 때 안에 작성된 코드를 실행하도록 합니다.
# `else` 안의 코드는 앞서 작성된 모든 조건이 거짓일 때 실행됩니다.
# ```python
# if 조건1:
#     코드
# elif 조건2:
#     코드
# else:
#     코드
# ```
# - `==` 두 대상이 같은지 비교하는 연산자입니다. 예를 들어 `1 == 2`는 거짓이고, `1 == 1`은 참이겠죠?

# %%
# 조건문을 활용하여 입력값으로 주어진 정보에 맞는 리스트를 찾아 출력해봅시다.
# Out:
# ['피부과', '연애, 결혼', '학교생활', '가수']

# %% [markdown]
# 3. 출력하고자 하는 순위를 입력하여 해당 순위의 관심분야만을 출력해봅시다.
# - 리스트는 `리스트명[인덱스번호]`와 같이 인덱스 번호를 통해 접근이 가능합니다.
# 인덱스 번호는 0부터 시작함에 유의하세요.
# - python에서의 입력값은 문자열로 저장됩니다. 그러나 인덱스 번호는 정수형이어야 합니다. 따라서 `int()` 함수로 형변환을 해주어야 합니다.

# %%
# 필요한 정보들을 입력받아 봅시다.

info =  ###성별, 연도, 나이대를 입력 받아봅시다.(입력 예시: 여자 2017년 10대)###

rank =  ###순위를 입력 받아봅시다.###
rank =  ###순위 정보를 int형으로 변환해봅시다.###


# 조건문을 활용하여 info에 맞는 리스트를 찾아 rank에 해당하는 요소를 출력해봅시다.
# Out:
# 성별, 연도, 나이대를 입력하세요(입력 예시: 여자 2017년 10대):  여자 2017년 10대
# 궁금한 순위를 입력하세요:  1
# 피부과

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 3</div>
#     <br>
#    워크시트 1과 2에서 했던 실습을 다른 성별, 연도, 나이대에 따른 다른 정보들에도 활용해봅시다. <br>
#     방금 전과 동일하게 관심분야 순위를 찾아 리스트에 저장한 후 조건문을 활용해 궁금한 정보들에 대해 접근해봅시다.
# </div>

# %%
#이곳에 코드를 작성해주세요.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">🚄 쉬어가기 (1)</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 전문가 인터뷰: 인공지능과 데이터 과학</div>
#
# </div>

# %% [markdown]
# **Q. 간단히 자기소개 부탁드립니다.**
# > 안녕하세요. 데이터 과학자 강병엽입니다. 머신러닝으로 박사학위를 받고 현재,
# 네이버에서 대용량 데이터 분석 및 인사이트 도출, 최신 머신러닝/인공지능을 연구하고 있습니다.

# %% [markdown]
# **Q. 최근 전 세계적으로 인공지능이 주목되고 있는데요. 인공지능은 어떻게 발전해왔나요?**
#
# > 인공지능은 최근 바둑으로 유명해진 알파고나 의료계에서 활용되는 왓슨을 통해 많이 알려지게
# 되었지만, 실제 인공지능 자체는 꽤나 오랜 역사를 가지고 있습니다. 인공지능이라는 단어는 1956년에
# 처음 사용되었고, 1990년대까지 인간처럼 문제를 해결할 수 있는 능력을 가진 인공지능 개발을
# 추진하였으나 결실을 맺지 못하였습니다. 2000년대가 되면서 컴퓨터성능의 급속한 발전과 인터넷의
# 발달로 수십 년 동안 꿈꾸던 인공지능의 구현이 가능하게 되었습니다.

# %% [markdown]
# **Q. 데이터 과학은 인공지능과 어떤 연관성이 있나요?**
#
# >인공지능의 핵심은 ‘성능 좋은 컴퓨터’와 인공지능이 학습하는데 필요한 ‘데이터’(빅데이터)라고
# 할 수 있습니다. 빠르게 일을 할 수 있는 고성능 컴퓨터와 데이터가 인공지능을 만드는데 반드시
# 필요한 요소입니다. 빅데이터는 이런 인공지능을 구현하기 위해 충분한 학습용 데이터를 공급해줍니다.
# 하지만, 여러 지식들을 체계적으로 분류하고, 그것들을 인공지능 학습에 사용할 수 있도록 준비하는 것은
# 아직까지 인간만이 할 수 있는 일입니다. 이러한 역할을 해주는 분야가 바로 ‘데이터 과학’입니다.

# %% [markdown]
# **Q. 인공지능 시대에 데이터 과학자로서 어떤 역할을 수행하고 계신가요?**
#
# > 저는 데이터 과학자로서 검색 사용자들의 데이터를 직접 분석하고 새로운 사실을 발견하는 업무를
# 수행합니다. 새롭게 발견한 사실을 활용해서, 검색 사용자들이 더 나은 서비스를 누릴 수 있도록
# 검색 사용자들을 도와주는 인공지능 모델을 직접 개발하기도 하지요. 또한, 사용자의 데이터를
# 분석해서 네이버 검색 서비스를 개선하기 위해서 노력합니다. 예를 들면, 검색 사용자들의 데이터를
# 분석해서 사용자들이 클릭하는 버튼의 위치가 불편하다는 사실을 발견하면, 클릭하는 버튼의 위치를
# 바꾸는 것이 좋다는 아이디어를 내기도 합니다. 그리고 검색어 순위가 자동으로 바뀔 수 있도록
# 인공지능 모델을 만들기도 하지요.

# %% [markdown]
# **Q. 데이터 과학자를 꿈꾸는 학생들을 위해, 어떻게 진로를 정하셨는지 설명 부탁드립니다.**
#
# > 저는 학창시절 수학을 좋아했습니다. 그 중에서 확률과 통계를 가장 좋아해 이쪽 분야를 계속
# 공부했습니다. 그리고 2012년 머신러닝으로 박사학위를 받았는데, 딱 그 시기가 빅데이터,
# 머신러닝 등이 한창 주목되던 때였습니다. 대학원 교수님께서 머신러닝을 전공하신 분이어서,
# 대학원 시절부터 운 좋게 최신 트렌드도 공부할 수 있었지요. 그래서 자연스럽게 인공지능,
# 데이터과학 쪽으로 진로를 결정하게 되었습니다.
