# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">지식iN 데이터를
# 분석해보자!</div>
#     <div style="font-weight: bold; font-size: 20px">[02] 네이버 지식iN 데이터 수집방법 알아보기</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     - 지식iN 데이터를 탐색하면서 다양한 데이터를 확인해봅시다.<br>
#     - 지식iN 데이터 수집방법을 탐색하고 데이터를 분석해봅시다.<br>
#     - 지식iN 데이터 분석 결과를 바탕으로 지식iN 홍보 이벤트를 기획해봅시다.<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 지식iN은 데이터를 어떻게 수집했을까?</h2>
# </div>

# %% [markdown]
# ### **1) 생각해봅시다**

# %% [markdown]
# 어떻게 데이터를 수집해서 이렇게 원 그래프로 표현할 수 있을까요? 생각해봅시다.
#
# ![image.png](attachment:aff11f6b-2ae9-47c0-b901-423cf785b9a5.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 1</div>
#     <br>
# 10대 남자라는 정보는 어떻게 얻었을까요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 2</div>
#     <br>
#  분야별 데이터 비율을 어떻게 얻었을까요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트 3</div>
#     <br>
# 전체 질문수, 답변수, 답변자 수 데이터를 어떻게 모았을까요?
# </div>

# %% [raw]
#  👉

# %% [markdown]
# 네이버 지식iN에서 질문을 작성하면, ‘분야 선택’ 창이 생깁니다. 여기서 해당되는 분야를 선택할 수 있습니다.
# ![image.png](attachment:aba66a4f-1972-4566-a904-89bcddd37208.png)

# %% [markdown]
# ### **2) 네이버 지식in 데이터 수집 방법**
#
# **‘네이버 개인정보처리방침’** 을 보면 자세한 내용을 확인할 수 있습니다. 회원제 서비스를 이용하기 위해
# 회원가입을 할 경우, 서비스를 위해 필요한 최소한의 (개인정보)를 수집하는 경우가 있습니다. 회원가입을
# 할 때 (성별), (생년월일) 등의 정보를 수집합니다.
# ![image.png](attachment:4a2ca743-a2c4-4c3d-b49f-89b3f8626c57.png)
# ![image.png](attachment:6390be93-3540-405c-b27d-50d7c5c1f152.png)
#
# 지식iN에 질문을 올리고 답변을 할 때의 정보를 축적하고 분류하여 통계를 낼 수 있습니다. 위 그림은 특정 시간을
# 기준으로 한 쇼핑 분야 통계 데이터입니다. 쇼핑 분야에서 연령대별, 성별로 답변한 비율을 시각화하여 확인할 수 있습니다.
#
# <br><br>
# 전체 질문수, 답변수, 답변자 수의 데이터는 어떻게 확인하고, 기록할 수 있을까요? 사람이 숫자를 일일이 세어
# 기록할 수 있으나 엄청나게 많은 노력과 시간이 필요합니다. 이 문제를 해결하기 위해 지식iN 데이터 수집을 컴퓨터
# 프로그래밍으로 자동화하였습니다. 지식iN에 질문을 올리고 답변을 작성하면 그 숫자가 체크가 되어 데이터가
# 저장됩니다. 사람이 직접 개수를 센다면 무척 오래 걸리겠지만 자동화 시스템을 만들었기 때문에 컴퓨터가 개수를 세고 통계를 냅니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 1</div>
#     <br>
# 친구들의 이름, 생년, 생월, 성별 정보를 알아보고 정보들을 리스트에 저장해봅시다.
# </div>

# %%
# 친구들의 이름, 생년, 생월, 성별 정보를 순서대로 저장하는 리스트를 생성해봅시다.
'''
    - 리스트 하나에 한 명의 정보만을 담아주세요.
    - 반드시 [이름, 생년, 생월, 성별] 순으로 정보를 저장해주세요.
    - 친구들의 이름을 변수명으로 저장해주세요.
    - 리스트 관련 내용은 1단원을 참고하세요.
'''

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 2</div>
#     <br>
# 친구들의 정보를 표로 만들어서 출력해봅시다. <br>
# </div>

# %% [markdown]
# 파이썬의 Pandas라이브러리는 dataframe이라는 자료형을 지원합니다.
# 1. `import pandas as pd` 코드로 Pandas 라이브러리를 pd라는 별칭으로 불러올 수 있습니다.
#
# 2. `pd.DataFrame(data=[데이터], columns=[열 이름들], index=[행 이름들])`과 같이 작성하여 표를 만들 수 있습니다.
#
# 앞서 선언한 name, year, mon, gender 리스트를 활용해서 친구들의 정보를 담은 DataFrame을 만들어보세요.
#
# 데이터를 어떻게 표로 표현하면 더 편하게 정보들을 확인할 수 있을까요?

# %%
# Pandas 라이브러리를 pd라는 별칭으로 불러와봅시다.

# %%
# pd.DataFrame 함수를 활용하여 친구들 정보로 이루어진 데이터프레임을 만들어 봅시다.
'''
    - DataFrame을 df라는 변수에 저장해주세요.
    - 변수명을 호출하면 데이터 표를 출력할 수 있습니다. 
'''
# Out:
#   name  year  mon gender
# 0  김철수  2005    8      m
# 1  김영희  2008    3      f
# 2  홍길동  2009    8      m
# 3  성춘향  2007    1      f
# 4  이몽룡  2005   12      m

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트 3</div>
#     <br>
# 위에서 작성한 데이터에서 여자와 남자가 각각 몇 명인지 알려주는 코드를 작성해볼까요?
# </div>

# %% [markdown]
# 1. `df['열이름'].value_counts()`는 특정 열에서 같은 value를 가진 행의 개수를 세어주는 코드입니다.

# %%
# 남자와 여자가 각각 몇명인지 세어주는 코드를 작성해봅시다.
# Out:
# gender
# m    3
# f    2
# Name: count, dtype: int64

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 지식iN은 어떤 데이터를 수집할까?</h2>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트</div>
#     <br>
# 지식iN에서 통계를 낼 때 중요한 데이터는 어떤 것이 있을까요?
#     <div style="font-weight: normal; font-size: 13px">
#         <br>
#         * ‘네이버 개인정보처리방침’을 보면 자세한 내용을 확인할 수 있습니다. 회원제 서비스를 이용하기 위해 회원가입을 할 경우, <br>
#         서비스를 위해 필요한 최소한의 ( 개인정보 )를 수집하는 경우가 있습니다. 회원가입시에 ( 성별 ), ( 생년월일 ) 등의 정보를 수집합니다. <br>
#         * 지식iN에서는 ( 나이 ), ( 성별 ), ( 기간 ), 분야 등을 기준으로 통계를 내고 있습니다.
#     </div>
# </div>

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1; font-weight: bold;">
# <h2 style='font-weight: bold'>※ 균형 잡힌 데이터의 중요성과 윤리적 문제</h2>
# </div>

# %% [markdown]
# ‘강아지-고양이 분류기 사례’와 ‘지식iN 데이터를 분석할 때 유의할 점’을 통해 균형 잡힌 데이터의 중요성과 윤리적 문제에 대해 생각해봅시다.
#
# ---

# %% [markdown]
# ### **(1) 강아지와 고양이 분류 인공지능이 잘 작동하려면?**
# 인공지능은 학습한 데이터에 따라 성능이 결정되는 경우가 많습니다. 어떤 데이터를 어떻게 학습했느냐에 따라 인공지능의 판단은 달라질 수 있습니다.
# 강아지와 고양이를 분류하는 인공지능을 만든다고 가정해봅시다. 인공지능이 학습할 데이터는 강아지와 고양이(2개의 클래스)로 나뉩니다.
# 만약 강아지 사진만 학습을 시킨다면, 고양이는 분류하지 못할 것입니다. 강아지 사진과 고양이 사진을 모두 학습시킨 경우는 고양이도 분류가 가능합니다.
#
# 데이터를 어떻게 훈련시켜야 인공지능이 강아지와 고양이를 잘 분류할 수 있을까요? 아래 질문에 답해보고 친구들과 의견을 나눠봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# Q. 아래에 제시된 강아지와 고양이 사진으로 인공지능을 학습시키면 어떻게 될까요?
# </div>
#
# <table>
# <tr>
#     <th><img src="https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/image/dissac/dissac_naver_1_01.png" width="750"></th>
#     </tr>
# <tr>
#     <th>강아지 고양이 분류</th>
# </tr>
# </table>

# %% [raw]
#  👉

# %% [markdown]
# 제시된 강아지, 고양이 사진으로만 인공지능을 학습시킬 경우 강아지와 고양이를 제대로 분류하지 못할 수 있습니다.
# 학습시킨 사진에서 강아지의 귀 모양은 모두 둥근 모양이며, 고양이의 귀 모양은 모두 뾰족한 모양입니다.
# 인공지능은 뾰족한 귀 모양을 가진 강아지 사진을 보고 고양이로 분류할 가능성이 높습니다.
#
# <table>
# <tr>
#     <th><img src="https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/image/dissac/dissac_naver_1_02.png" width="750"></th>
#     </tr>
# <tr>
#     <th>강아지 분류 오류</th>
# </tr>
# </table>
#
# 이처럼 학습 데이터가 부족하거나 균형이 잡히지 않은 경우, 인공지능도 한 쪽으로 치우친 판단을 할 가능성이 높습니다.

# %% [markdown]
# ### **2) 지식iN 데이터를 분석할 때 유의할 점**
#
# 우리가 지식인의 데이터를 보고 판단을 할 때 유의해야 할 점은 무엇일까요?
# 아래 그래프를 통해 생각해봅시다. 이 그래프는 2020년 7월에 10대 남성이 네이버 지식iN에서 어떤 분야에 대한 질문을 많이 올렸는지 보여줍니다.
#
# <table>
# <tr>
#     <th><img src="https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/image/dissac/dissac_naver_1_03.png" width="750"></th>
#     </tr>
# <tr>
#     <th>데이터 분석 유의사항</th>
# </tr>
# </table>
#
# **이 데이터만으로 모든 10대 남성이 연애와 결혼에 관심이 많다고 판단할 수 있을까요?**
# 그렇게 일반화 하기는 어렵습니다. 그 이유는 ‘특정 시기에 지식iN을 활용한 10대 남성’에 대한 데이터이기 때문입니다.
# 2020년 7월에 인기 연예인이 연애나 결혼을 하여 갑자기 관심이 높아졌을 수도 있고, 연애나 결혼에 관심 있는 일부 사람들이
# 지식iN을 많이 활용했을 수 있습니다. 따라서 다른 시기에는 어땠는지, 지식iN을 활용하지 않은 사람은 어떤지 추가로 확인하면,
# 데이터를 정확하게 분석하는데 도움이 될 것입니다.
#
# <br>
#
# 앞서 강아지-고양이 분류기 사례를 통해 **균형 잡히지 않은 데이터를 학습한 인공지능은 판단도 한쪽으로 치우칠 수 있다** 는 것을 배웠습니다.
# 아울러, 지식iN 데이터 분석 시 유의할 점을 통해 **데이터가 어떤 시기에 어떤 경로를 통해 수집된 것인지 명확히 알아야 한다** 는 점을 배웠습니다.
# 인공지능의 편향된 판단이나 잘못된 데이터 분석 결과는 **사회적, 윤리적 문제** 로 이어질 수 있으니 항상 주의해야 합니다.
