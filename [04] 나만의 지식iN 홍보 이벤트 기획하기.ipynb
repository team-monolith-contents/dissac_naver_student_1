# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">지식iN 데이터를
# 분석해보자!</div>
#     <div style="font-weight: bold; font-size: 20px">[04] 나만의 지식iN 홍보 이벤트 기획하기</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     - 지식iN 데이터를 탐색하면서 다양한 데이터를 확인해봅시다.<br>
#     - 지식iN 데이터 수집방법을 탐색하고 데이터를 분석해봅시다.<br>
#     - 지식iN 데이터 분석 결과를 바탕으로 지식iN 홍보 이벤트를 기획해봅시다.<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 홍보 이벤트 기획하기</h2>
# </div>

# %% [markdown]
# ![image.png](attachment:7000e8bf-56a4-469f-872f-b944628df53c.png)
#
# 엔트리봇은 지식iN을 활용해 제비 날개를 고치는 데 필요한 정보를 얻을 수 있었습니다. 지식iN에는 다양한 정보
# 가 있기 때문에 이를 바탕으로 생활 속 많은 문제를 해결하는데 도움을 얻을 수 있습니다. 또한, 지식iN의 질문과
# 답변을 통해, 비슷한 궁금증을 가졌던 다른 사람들에게도 도움을 줄 수 있습니다.
#
#
# 한편, 네이버는 지식iN을 사람들이 많이 활용하도록 다양한 이벤트를 진행하고 있습니다. 2020년 9월 지식iN에
# 서는 룰렛 이벤트를 진행하기도 했습니다. 네이버페이, 쿠폰, 내공 등을 제공하며 지식iN 활동을 적극 홍보했지요.
#
# ![image.png](attachment:d0da67c1-83b8-4ea0-a439-4ff0a58f7f4f.png)
#
# 우리도 사람들이 네이버 지식iN을 많이 사용하도록 재미있는 이벤트를 기획해봅시다. 창의적이면서 현실적인
# 이벤트를 기획하고 서로 평가해봅시다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크 시트</div>
#     <br>
# 내가 만든 프로그램을 친구들에게 발표해봅시다!
# </div>
#
# ![image.png](attachment:de3e76a5-1cac-447d-b216-f8c31edc6b11.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 가장 창의적이고 현실적인 이벤트 선정하기</h2>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">⭐ 오늘의 MVP</div>
#     <br>
# 우리 반 친구들은 어떤 이벤트를 만들었나요? <br>
# 가장 창의적이고 현실적으로 기획한 이벤트를 선정하여 장점을 적어봅시다.
# </div>
#
# ![image.png](attachment:2b654329-3305-4cce-9573-1188baf9676e.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 심화: 검색어 트렌드를 활용하여 데이터 분석하기</h2>
# </div>

# %% [markdown]
# 지식iN에서 데이터를 분석했을 때 컴퓨터통신, 게임, 엔터테인먼트, 쇼핑 등 다양한 분야별로 정보를 확인할 수
# 있었습니다. 이번에는 **네이버 데이터랩** 을 활용해 여러 가지 데이터를 분석해보겠습니다. ‘네이버 데이터랩’은
# 네이버의 검색 트렌드 및 급상승검색어 이력, 쇼핑 카테고리별 검색 트렌드 제공하는 서비스입니다. 그중에서
# **‘검색어 트렌드’** 를 활용하면 네이버 통합검색에서 특정 단어의 검색량을 시각적으로 표현한 것을 확인할 수 있
# 습니다.

# %% [markdown]
# 네이버 홈페이지에서 ‘더보기’를 클릭합니다.
#
# ![image.png](attachment:711b64f7-b6cb-4a8d-9267-b6f710e5ae71.png)
# <br><br>
#
#
#
# 왼쪽에 ‘데이터랩’을 클릭합니다. 혹은 네이버 검색창에 ‘네이버 데이터랩’을 검색한 후 ‘네이버 데이터랩’을 클릭해 접속하셔도 됩니다.
#
# ![image.png](attachment:e55fbb1e-2822-4e96-9fd0-c88a1066987a.png)
# <br><br>
#
#
#
#
# **네이버 데이터랩 홈페이지**를 보시면 데이터랩 홈, 급상승검색어, 검색어트렌드, 쇼핑인사이트 등의 메뉴를 확인할 수 있습니다.
# ‘데이터랩 홈’의 ‘쇼핑인사이트’에서는 쇼핑 분야별 검색어 현황을 확인할 수 있습니다.
#
# ![image.png](attachment:29a59912-0e39-42df-983a-5649725d9e50.png)
# <br><br>
#
#
#
# **‘급상승 검색어’** 에서는 시간, 연령, 관심사 등을 설정하면 검색 횟수가 급상승한 검색어 순위를 확인할 수 있습니다.
#
# ![image.png](attachment:df3ac51b-67c9-4b6e-98bc-4ce7377a5d1e.png)
# <br><br>
#
#
# **‘검색어 트렌드’** 에서는 네이버 통합검색에서 특정 검색어가 얼마나 많이 검색되었는지 확인해볼 수 있습니다.
#
# ![image.png](attachment:0eb9f7b9-5e59-4d31-96a1-b37b00841196.png)
# <br><br>
#
#
# 주제어1에 ‘캠핑’. 주제어1에 해당하는 검색어 ‘캠핑, 캠핑용품, 캠핑요리’를 입력해봅시다.
# (복잡하다고 느껴진다면 주제어1에만 ‘캠핑’ 검색어를 입력해도 괜찮습니다)
#
# ![image.png](attachment:d1752607-4906-4f6d-ba39-e3707be82298.png)
# <br><br>
#
#
#
# 기간, 범위(모바일, PC), 성별, 연령 등에 대한 세부설정을 할 수도 있습니다.
# 기간을 ‘2019년 9월 26일’에서 ‘2020년 9월 26일’로 변경하고 ‘네이버 검색 데이터 조회’를 클릭해주세요.
#
# ![image.png](attachment:c69ed593-8912-481c-85b7-fe029392f0d2.png)
# <br><br>
#
#
#
# 결과를 확인해보겠습니다. 2020년 3월 29일 이후부터 ‘캠핑’ 검색량이 눈에 띄게 증가하는 것을 확인할 수 있습니다.
# 그 이유는 겨울이 지나고 날씨가 따뜻해지는 봄에 캠핑을 많이 가기 때문이라고 추측할 수 있습니다.
#
# ![image.png](attachment:bc45862a-f198-4792-b05a-06e927c647b6.png)
# <br><br>
#
#
# 이번에는 ‘패딩’으로 검색한 결과입니다. 결과를 보면 겨울에 검색량이 많은 것을 확인할 수 있습니다.
# 이렇게 기간별로 특정 단어의 검색량을 확인할 수 있습니다. 여러분도 ‘검색어 트렌드’를 활용해 다양한 데이터를 검색하고 분석해보세요.
#
# ![image.png](attachment:0fe6da8a-df4c-4324-8783-9f6bf5c4fa7f.png)
# <br><br>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 워크시트</div>
#     <br>
# 검색해보고자 하는 검색어들의 리스트를 만들고, 반복문을 활용해 검색 링크를 만들어봅시다.
# </div>

# %%
# 검색해보고자 하는 검색어 리스트를 만들어 봅시다. 
words = ???

# 검색어 리스트의 요소들을 순회하며 검색 링크를 만들어봅시다. 
'''
    - 링크형식: https://search.naver.com/search.naver?query=검색어명
    - 문자열 내 검색어명 삽입 방법: f'~~~{삽입내용}'
'''
# Out:
# 캠핑 검색 링크는 https://search.naver.com/search.naver?query=캠핑
# 패딩 검색 링크는 https://search.naver.com/search.naver?query=패딩
# 원피스 검색 링크는 https://search.naver.com/search.naver?query=원피스
# 휴무일 검색 링크는 https://search.naver.com/search.naver?query=휴무일
# 고종 검색 링크는 https://search.naver.com/search.naver?query=고종
